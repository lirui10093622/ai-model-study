# %%
from transformers import pipeline

checkpoint = "google/owlvit-base-patch32"
detector = pipeline("zero-shot-object-detection", checkpoint)
predictions = detector(image = image, candidate_labels=["hat", "sunglass"])
predictions
# Out:
# hi
